# %%
import json
from utils import *
from run import run_, RASTRIGIN_ARGS, ROSENBROCK_ARGS, ACKLEY_ARGS, SCHWEFEL_ARGS
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib created a temporary config/cache directory at /var/folders/mm/21xbg4_932b512rnb97rm9tw0000gn/T/matplotlib-jpsdy1ms because the default path (/Users/marc/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
args = RASTRIGIN_ARGS
filename_ = "rastrigin_es"

run_(args, filename=filename_, n_runs=3)
display(args)
# Out:
# 'Solutions: 1 of 0, Time elapsed: 1068.23 s'
# 'RUN 0 STATUS: FOUND       in 1068.23s and 313 iterations'
# Iteration:  0
# Best fitness:  412.86591276472916
# Iteration:  1
# Best fitness:  351.3817236826004
# Iteration:  2
# Best fitness:  330.5421308692722
# Iteration:  3
# Best fitness:  316.7923144444428
# Iteration:  4
# Best fitness:  288.70158406365846
# Iteration:  5
# Best fitness:  267.95662076067634
# Iteration:  6
# Best fitness:  213.69579047114394
# Iteration:  7
# Best fitness:  213.69579047114394
# Iteration:  8
# Best fitness:  212.212511052246
# Iteration:  9
# Best fitness:  174.93873397641175
# Iteration:  10
# Best fitness:  169.54845966589403
# Iteration:  11
# Best fitness:  164.92161566567654
# Iteration:  12
# Best fitness:  141.62825209305373
# Iteration:  13
# Best fitness:  114.06899316026514
# Iteration:  14
# Best fitness:  111.64495000815083
# Iteration:  15
# Best fitness:  92.68833049850446
# Iteration:  16
# Best fitness:  72.74130682913582
# Iteration:  17
# Best fitness:  68.12270600722701
# Iteration:  18
# Best fitness:  56.550956775015976
# Iteration:  19
# Best fitness:  54.64511751626165
# Iteration:  20
# Best fitness:  44.318453790423916
# Iteration:  21
# Best fitness:  39.202459675680984
# Iteration:  22
# Best fitness:  30.489774235045104
# Iteration:  23
# Best fitness:  30.489774235045104
# Iteration:  24
# Best fitness:  27.182228849806222
# Iteration:  25
# Best fitness:  25.04771945037396
# Iteration:  26
# Best fitness:  21.56587110477983
# Iteration:  27
# Best fitness:  17.759496881472103
# Iteration:  28
# Best fitness:  17.759496881472103
# Iteration:  29
# Best fitness:  15.182786485553834
# Iteration:  30
# Best fitness:  13.077249429831284
# Iteration:  31
# Best fitness:  12.709576161390544
# Iteration:  32
# Best fitness:  9.615736498950298
# Iteration:  33
# Best fitness:  8.65831841300195
# Iteration:  34
# Best fitness:  7.2097438366520805
# Iteration:  35
# Best fitness:  5.648603277446966
# Iteration:  36
# Best fitness:  5.435463961422613
# Iteration:  37
# Best fitness:  4.334690097904343
# Iteration:  38
# Best fitness:  4.310460391212359
# Iteration:  39
# Best fitness:  3.8178299978158066
# Iteration:  40
# Best fitness:  3.193352476385087
# Iteration:  41
# Best fitness:  2.6757084363662216
# Iteration:  42
# Best fitness:  2.6757084363662216
# Iteration:  43
# Best fitness:  2.635121901913635
# Iteration:  44
# Best fitness:  2.486090180292706
# Iteration:  45
# Best fitness:  2.486090180292706
# Iteration:  46
# Best fitness:  2.486090180292706
# Iteration:  47
# Best fitness:  2.2230457414389093
# Iteration:  48
# Best fitness:  2.1859095902991044
# Iteration:  49
# Best fitness:  2.1859095902991044
# Iteration:  50
# Best fitness:  2.1329610421518623
# Iteration:  51
# Best fitness:  2.1329610421518623
# Iteration:  52
# Best fitness:  2.0798425165613708
# Iteration:  53
# Best fitness:  1.9550087792959516
# Iteration:  54
# Best fitness:  1.9550087792959516
# Iteration:  55
# Best fitness:  1.899099727212615
# Iteration:  56
# Best fitness:  1.7560736775747614
# Iteration:  57
# Best fitness:  1.7196682685052451
# Iteration:  58
# Best fitness:  1.6153656853266511
# Iteration:  59
# Best fitness:  1.5033943167420034
# Iteration:  60
# Best fitness:  1.5033943167420034
# Iteration:  61
# Best fitness:  1.5033943167420034
# Iteration:  62
# Best fitness:  1.5033943167420034
# Iteration:  63
# Best fitness:  1.5033943167420034
# Iteration:  64
# Best fitness:  1.4170409778280941
# Iteration:  65
# Best fitness:  1.4170409778280941
# Iteration:  66
# Best fitness:  1.4170409778280941
# Iteration:  67
# Best fitness:  1.406367514511544
# Iteration:  68
# Best fitness:  1.3966769657422446
# Iteration:  69
# Best fitness:  1.3966769657422446
# Iteration:  70
# Best fitness:  1.3935234301883952
# Iteration:  71
# Best fitness:  1.3935234301883952
# Iteration:  72
# Best fitness:  1.3678437903859617
# Iteration:  73
# Best fitness:  1.3678437903859617
# Iteration:  74
# Best fitness:  1.3678437903859617
# Iteration:  75
# Best fitness:  1.3068960372370952
# Iteration:  76
# Best fitness:  1.3068960372370952
# Iteration:  77
# Best fitness:  1.263408442859884
# Iteration:  78
# Best fitness:  1.263408442859884
# Iteration:  79
# Best fitness:  1.263408442859884
# Iteration:  80
# Best fitness:  1.263408442859884
# Iteration:  81
# Best fitness:  1.263408442859884
# Iteration:  82
# Best fitness:  1.263408442859884
# Iteration:  83
# Best fitness:  1.263408442859884
# Iteration:  84
# Best fitness:  1.263408442859884
# Iteration:  85
# Best fitness:  1.263408442859884
# Iteration:  86
# Best fitness:  1.263408442859884
# Iteration:  87
# Best fitness:  1.263408442859884
# Iteration:  88
# Best fitness:  1.263408442859884
# Iteration:  89
# Best fitness:  1.263408442859884
# Iteration:  90
# Best fitness:  1.263408442859884
# Iteration:  91
# Best fitness:  1.263408442859884
# Iteration:  92
# Best fitness:  1.263408442859884
# Iteration:  93
# Best fitness:  1.263408442859884
# Iteration:  94
# Best fitness:  1.263408442859884
# Iteration:  95
# Best fitness:  1.2610483565491108
# Iteration:  96
# Best fitness:  1.2610483565491108
# Iteration:  97
# Best fitness:  1.2610483565491108
# Iteration:  98
# Best fitness:  1.2610483565491108
# Iteration:  99
# Best fitness:  1.2257494959545738
# Iteration:  100
# Best fitness:  1.2257494959545738
# Iteration:  101
# Best fitness:  1.2257494959545738
# Iteration:  102
# Best fitness:  1.2257494959545738
# Iteration:  103
# Best fitness:  1.2257494959545738
# Iteration:  104
# Best fitness:  1.2257494959545738
# Iteration:  105
# Best fitness:  1.2257494959545738
# Iteration:  106
# Best fitness:  1.2257494959545738
# Iteration:  107
# Best fitness:  1.2257494959545738
# Iteration:  108
# Best fitness:  1.2257494959545738
# Iteration:  109
# Best fitness:  1.2257494959545738
# Iteration:  110
# Best fitness:  1.2257494959545738
# Iteration:  111
# Best fitness:  1.2257494959545738
# Iteration:  112
# Best fitness:  1.2257494959545738
# Iteration:  113
# Best fitness:  1.2257494959545738
# Iteration:  114
# Best fitness:  1.2257494959545738
# Iteration:  115
# Best fitness:  1.2257494959545738
# Iteration:  116
# Best fitness:  1.2257494959545738
# Iteration:  117
# Best fitness:  1.2257494959545738
# Iteration:  118
# Best fitness:  1.2257494959545738
# Iteration:  119
# Best fitness:  1.2257494959545738
# Iteration:  120
# Best fitness:  1.2257494959545738
# Iteration:  121
# Best fitness:  1.2257494959545738
# Iteration:  122
# Best fitness:  1.2257494959545738
# Iteration:  123
# Best fitness:  1.2257494959545738
# Iteration:  124
# Best fitness:  1.2257494959545738
# Iteration:  125
# Best fitness:  1.2257494959545738
# Iteration:  126
# Best fitness:  1.2257494959545738
# Iteration:  127
# Best fitness:  1.2257494959545738
# Iteration:  128
# Best fitness:  1.2257494959545738
# Iteration:  129
# Best fitness:  1.1634699163551545
# Iteration:  130
# Best fitness:  1.1634699163551545
# Iteration:  131
# Best fitness:  1.1634699163551545
# Iteration:  132
# Best fitness:  1.1634699163551545
# Iteration:  133
# Best fitness:  1.1634699163551545
# Iteration:  134
# Best fitness:  1.1634699163551545
# Iteration:  135
# Best fitness:  1.1634699163551545
# Iteration:  136
# Best fitness:  1.1634699163551545
# Iteration:  137
# Best fitness:  1.1634699163551545
# Iteration:  138
# Best fitness:  1.1634699163551545
# Iteration:  139
# Best fitness:  1.1634699163551545
# Iteration:  140
# Best fitness:  1.1634699163551545
# Iteration:  141
# Best fitness:  1.1634699163551545
# Iteration:  142
# Best fitness:  1.1634699163551545
# Iteration:  143
# Best fitness:  1.1634699163551545
# Iteration:  144
# Best fitness:  1.1634699163551545
# Iteration:  145
# Best fitness:  1.1634699163551545
# Iteration:  146
# Best fitness:  1.1634699163551545
# Iteration:  147
# Best fitness:  1.1634699163551545
# Iteration:  148
# Best fitness:  1.1634699163551545
# Iteration:  149
# Best fitness:  1.1634699163551545
# Iteration:  150
# Best fitness:  1.1634699163551545
# Iteration:  151
# Best fitness:  1.1634699163551545
# Iteration:  152
# Best fitness:  1.1512271977397859
# Iteration:  153
# Best fitness:  1.1512271977397859
# Iteration:  154
# Best fitness:  1.1512271977397859
# Iteration:  155
# Best fitness:  1.1512271977397859
# Iteration:  156
# Best fitness:  1.1512271977397859
# Iteration:  157
# Best fitness:  1.1512271977397859
# Iteration:  158
# Best fitness:  1.1512271977397859
# Iteration:  159
# Best fitness:  1.1512271977397859
# Iteration:  160
# Best fitness:  1.1512271977397859
# Iteration:  161
# Best fitness:  1.1512271977397859

# %%
with open(filename_ + '.json', 'r') as f:
    data_rastrigin = json.load(f)

# %% [markdown]
# ### Média de iterações para o algoritmo convergir

# %%
solutions = [i for i in data_rastrigin if i["found_solution"]]

iterations_info = [i["iterations"] for i in solutions]

iterations_mean = np.mean(iterations_info)
rounded_mean = round(iterations_mean, 2)

iterations_std = np.std(iterations_info)
rounded_std = round(iterations_std, 2)

plt.figure(figsize=(10, 5))
plt.title("Iterations to find solution")
plt.xlabel("Runs")
plt.ylabel("Iterations")
plt.ylim(700, 1400)

plt.plot(iterations_info)
for i in range(len(iterations_info)):
    plt.text(i, iterations_info[i], str(iterations_info[i]), ha='center', va='bottom', color='black')
    
# put mean as a red line
plt.axhline(y=iterations_mean, color='r', linestyle='--')
plt.text(0, rounded_mean + 10, "Mean: " + str(rounded_mean), color='r')

# put std as a green line
#plt.axhline(y=rounded_std, color='g', linestyle='--')
plt.text(0, rounded_mean - 50, "Std: " + str(rounded_std), color='g')

# %% [markdown]
# ### Fitness médio da população (média da média)

# %%
mean_fitness_per_iteration = []
for run in data_rastrigin:
    mean_fitness_per_iteration.append(np.mean(run["mean_per_iteration"]))
    
    
plt.figure(figsize=(10, 5))
plt.title("Fitness per iteration")
plt.bar(range(len(mean_fitness_per_iteration)), mean_fitness_per_iteration, )

for i in range(len(mean_fitness_per_iteration)):
    plt.text(i, mean_fitness_per_iteration[i], f"{mean_fitness_per_iteration[i]:.2f}", ha="center", va="bottom")

plt.axhline(y=np.mean(mean_fitness_per_iteration), color="red", linestyle="--", label="Mean")

# %% [markdown]
# ### Fitness médio da ultima geração

# %%
mean_last_pop = []
for run in data_rastrigin:
    mean_last_pop.append(np.mean(run["last_population_fitness"]))

mean = np.mean(mean_last_pop)
std = np.std(mean_last_pop)

plt.figure(figsize=(10, 8))
plt.title("Mean last population fitness")
plt.xlabel("Run")
plt.ylabel("Mean fitness")

plt.bar(range(len(mean_last_pop)), mean_last_pop, yerr=std, capsize=5)

    
plt.axhline(y=mean, color='r', linestyle='--')
plt.text(-0.7, mean, "Mean: " + str(round(mean, 2)), ha="center", color='r')

# %% [markdown]
# ### Gráficos de convergência

# %%
# max

datas_max = []
datas_max.append(max(solutions, key=lambda x: x["iterations"]))

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

ax1.set_title("Mean fitness x Iterations")
ax1.set_ylabel("Mean fitness")
ax1.grid(True)

ax2.set_ylabel("Mean fitness")
ax2.set_xlabel("Iterations")
ax2.grid(True)

for i in range(len(datas_max)):
    mean_per_iteration = datas_max[i]["mean_per_iteration"]
    best_per_iteration = datas_max[i]["best_per_iteration"]
    
    ax2.plot(mean_per_iteration, color='green', label='Mean Fitness')
    ax2.plot(best_per_iteration, color='red', label='Best Fitness')
    
    ax1.plot(mean_per_iteration, color='green', label='Mean Fitness')
    ax1.plot(best_per_iteration, color='red', label='Best Fitness')
    
    
    # Defina os limites do eixo y na primeira subtrama
    ax1.set_ylim(0, 50)
    
    ax1.legend()  # Adicione uma legenda à primeira subtrama

plt.show()
